# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
businessdata = pd.read_csv('full_business_id.csv')

# %%
businessdata.head()
# Out:
#    Unnamed: 0                      id                                   alias  \
# 0           0  4Vmq51yYzlDEzCQ03zPsGg           hironori-craft-ramen-irvine-3
# 1           1  Ca1fXrIAHItmzjciPrNdvA               duck-donuts-irvine-irvine
# 2           2  ObCj8Y3KAdk4bgc8oSxNcA  bosscat-kitchen-and-libations-irvine-3
# 3           3  3TuRCJyqJzQehpcubbJs9g               baekjeong-irvine-irvine-2
# 4           4  NVB2X8t5Rie8S5AnzOnWJg                     north-italia-irvine
#
#                             name  \
# 0           HiroNori Craft Ramen
# 1           Duck Donuts - Irvine
# 2  Bosscat Kitchen and Libations
# 3             Baekjeong - Irvine
# 4                   North Italia
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/zMlMh3...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/HOOwA4...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRk...      False
# ...

# %%
businessdata.columns
# Out:
# Index(['Unnamed: 0', 'id', 'alias', 'name', 'image_url', 'is_closed', 'url',
#        'review_count', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'address1', 'address2', 'address3', 'city',
#        'zip_code', 'country', 'state', 'display_address', 'latitude',
#        'longitude', 'alias0', 'title0', 'alias1', 'title1', 'alias2',
#        'title2'],
#       dtype='object')

# %%
list(businessdata.groupby('city')['rating'].mean())
# Out:
# [4.5,
#  4.310344827586207,
#  4.0,
#  4.5,
#  4.0,
#  4.247368421052632,
#  4.5,
#  4.428571428571429,
#  4.326086956521739,
#  4.4,
#  3.92621359223301,
#  4.3,
#  4.5,
#  4.5,
#  4.5,
#  4.2894736842105265,
#  4.666666666666667,
#  4.2375,
#  3.8333333333333335,
#  4.239130434782608,
#  4.5,
#  4.5,
#  4.352112676056338,
#  4.121621621621622,
#  4.166666666666667]

# %%
list(businessdata['city'].unique())
# Out:
# ['Irvine',
#  'Tustin',
#  'Costa Mesa',
#  'Newport Beach',
#  'Santa Ana',
#  'Fountain Valley',
#  'Anaheim',
#  'Laguna Hills',
#  'Garden Grove',
#  'Orange',
#  'Laguna Beach',
#  'Lake Forest',
#  'Huntington Beach',
#  'Corona del Mar',
#  'Westminster',
#  'Newport Coast',
#  'Mission Viejo',
#  'Corona Del Mar',
#  'Laguna Woods',
#  'Buena Park',
#  'Foothill Ranch',
#  'Laguna Niguel',
#  'San Juan Capistrano',
#  'Rancho Santa Margarita',
#  'Aliso Viejo']

# %%
d = pd.DataFrame({'city':list(businessdata['city'].unique()),'rating':list(businessdata.groupby('city')['rating'].mean())} )

# %%
d.head()
# Out:
#             city    rating
# 0         Irvine  4.500000
# 1         Tustin  4.310345
# 2     Costa Mesa  4.000000
# 3  Newport Beach  4.500000
# 4      Santa Ana  4.000000

# %%
plt.figure(figsize=(60,30))
sns.set_style("darkgrid")
sns.barplot(data = d,x = 'rating',y='city')
plt.yticks(fontsize=24)
plt.xticks(fontsize=24)
# Out:
# (array([0., 1., 2., 3., 4., 5.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
userreviews = pd.read_csv('full_reviews.csv')

# %%
userreviews.shape
# Out:
# (3000, 11)

# %%
userreviews['id'].nunique()
# Out:
# 2968

# %%
hmap = businessdata[(businessdata['price']=='$')|(businessdata['price']=='$$')|(businessdata['price']=='$$$')]

# %%
hmap['price'].value_counts()
# Out:
# $$     664
# $      183
# $$$     57
# Name: price, dtype: int64

# %%
hmap = hmap.head(10)

# %%
hmap.columns
# Out:
# Index(['Unnamed: 0', 'id', 'alias', 'name', 'image_url', 'is_closed', 'url',
#        'review_count', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'address1', 'address2', 'address3', 'city',
#        'zip_code', 'country', 'state', 'display_address', 'latitude',
#        'longitude', 'alias0', 'title0', 'alias1', 'title1', 'alias2',
#        'title2'],
#       dtype='object')

# %%
hmap.set_index('name',inplace=True)

# %%
hmap.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# /var/folders/w7/r3sj_l0s11j7mjvdks7hxdzw0000gn/T/ipykernel_99331/783992744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hmap.drop('Unnamed: 0',axis=1,inplace=True)

# %%
hmap.columns
# Out:
# Index(['id', 'alias', 'image_url', 'is_closed', 'url', 'review_count',
#        'rating', 'transactions', 'price', 'phone', 'display_phone', 'distance',
#        'address1', 'address2', 'address3', 'city', 'zip_code', 'country',
#        'state', 'display_address', 'latitude', 'longitude', 'alias0', 'title0',
#        'alias1', 'title1', 'alias2', 'title2'],
#       dtype='object')

# %%
hmap.shape
# Out:
# (904, 30)

# %%
hmap.drop_duplicates(subset=['name'],inplace=True)
# Out:
# /var/folders/w7/r3sj_l0s11j7mjvdks7hxdzw0000gn/T/ipykernel_99331/1472403264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hmap.drop_duplicates(subset=['name'],inplace=True)

# %%
hmap.shape
# Out:
# (836, 30)

# %%
hmap.replace('$$',2,inplace=True)
hmap.replace('$$$',3,inplace=True)
# Out:
# /var/folders/w7/r3sj_l0s11j7mjvdks7hxdzw0000gn/T/ipykernel_99331/4235845028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hmap.replace('$$',2,inplace=True)
# /var/folders/w7/r3sj_l0s11j7mjvdks7hxdzw0000gn/T/ipykernel_99331/4235845028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hmap.replace('$$$',3,inplace=True)

# %%
hmap['price'].value_counts()
# Out:
# 2    623
# 1    157
# 3     56
# Name: price, dtype: int64

# %%
d = hmap.pivot('name','rating','price')

# %%
d
# Out:
# rating                          2.5  3.0  3.5  4.0  4.5  5.0
# name
# 3 Blossoms Cafe                 NaN  NaN  NaN  NaN  1.0  NaN
# 4th Street Market               NaN  NaN  NaN  2.0  NaN  NaN
# 7 Leaves Cafe                   NaN  NaN  NaN  1.0  NaN  NaN
# 85°C Bakery Cafe-Irvine         NaN  NaN  NaN  1.0  NaN  NaN
# A & J Restaurant                NaN  NaN  NaN  2.0  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...
# bb.q Chicken - Tustin           NaN  NaN  NaN  NaN  2.0  NaN
# bb.q Chicken Northpark, Irvine  NaN  NaN  2.0  NaN  NaN  NaN
# bouillon MOULIN                 NaN  NaN  NaN  NaN  2.0  NaN
# dPot                            NaN  NaN  NaN  NaN  2.0  NaN
# solita Tacos & Margaritas       NaN  NaN  NaN  2.0  NaN  NaN
#
# [836 rows x 6 columns]

# %%
sns.set_style("dark")
sns.heatmap(d.head(100),cmap="crest")
# Out:
# <AxesSubplot:xlabel='rating', ylabel='name'>

# %%
businessdata['alias0'].nunique()
# Out:
# 116

# %%
d = pd.DataFrame({'cuisine':list(businessdata['alias0'].unique()),'rating' : list(businessdata.groupby('alias0')['rating'].mean())})

# %%
plt.figure(figsize=(60,30))
sns.set_style("darkgrid")
sns.barplot(data = d.head(20),x = 'rating',y='cuisine')
plt.yticks(fontsize=24)
plt.xticks(fontsize=24)
# Out:
# (array([0., 1., 2., 3., 4., 5.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
p = hmap.pivot('name','rating','review_count')

# %%
sns.set_style("dark")
sns.heatmap(p,cmap="crest")
# Out:
# <AxesSubplot:xlabel='rating', ylabel='name'>
